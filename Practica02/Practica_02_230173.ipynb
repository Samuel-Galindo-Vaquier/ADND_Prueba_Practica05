# %% [markdown]
# # Analitica de Datos para Negocios Digitales

# %% [markdown]
# ## Práctica 02: Introducción al Uso de Python en el Análisis de Datos

# %% [markdown]
# **Elaborado por:** Samuel Galindo Vaquier
#
# **Grado/Grupo:** 9°A IEVND
#
# **Matricula:** 230173

# %% [markdown]
# 1. **Importamos las librerías Python para la manipulación y análisis de datos.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat
import seaborn as sea

# %% [markdown]
# 2. **Creamos un DataFrame del Origen de los Dat5os en este caso un archivo delimitado por comas**
#
# Este comando permite cargar en memoria caché (temporal), los datos que se van a analizar, esto utilizando la libreria **PANDAS** que nos permite la manipulación de datos.

# %%
df=pd.read_csv('UberDataset.csv')
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# 3. **Imprimimos en pantalla los datos cargados para verificar la carga correcta**
#
# **Importante:** La impresión de los datos del DATAFRAME no da contexto importante como el número de filas, el número de columnas, y en caso de datos **CUANTITATIVOS** una suma del total de la columna, en caso de los datos **CUALITATIVOS** nos colocará en texto NaN (Not as Number) por defecto no se pueden sumar.

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# 4. **Leer los datos de una columna específica**
#
# El uso de **['COLUMNA']** nos permite poder acceder a los datos de la columna del Dataframe, mostrando los 5 primeros y los 5 últimos, el total de registros y el tipo de datos, cabe mencionar que este comando

# %%
df['PURPOSE']
# Out:
# 0        Meal/Entertain
# 1                   NaN
# 2       Errand/Supplies
# 3               Meeting
# 4        Customer Visit
#              ...
# 1151     Temporary Site
# 1152            Meeting
# 1153     Temporary Site
# 1154     Temporary Site
# 1155                NaN
# Name: PURPOSE, Length: 1156, dtype: object

# %% [markdown]
# 5. **Manipulamos los datos cargados para obtener el total de cada valor registrado en la columna**
#
# El método value_counts() es una función preprogramada de *Python* que nos permite agrupar los registros por sus valores y obtener el total de cada valor detectado.

# %%
df['PURPOSE'].value_counts()
# Out:
# PURPOSE
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: count, dtype: int64

# %% [markdown]
# 6. **Aplicamos la misma función con otra columna**
#
# En este caso vemos que tipo de viaje hizo el conductor, resultando **"Bussiness"** (Negocios) o **"Personal"** (Asuntos Personales).

# %%
df['CATEGORY'].value_counts()
# Out:
# CATEGORY
# Business    1078
# Personal      77
# Name: count, dtype: int64

# %% [markdown]
# 7. **Limpiamos el DataFrame de los viajes que no tienen un destino localizable**
#
# Para este análisis es importante limpiar los datos de la muestra que nos sirven para nuestro análisis, empezaremos por eliminar los registros (Filas), de aquellos viajes que no registraron un destino localizable. Para ello utilizamos el comando lógico de no igualdad (!=) para filtrar el dataframe, esto nos arrojará un resultado de booleano "True" para los que tienen un destino localizable y "False" para los que no.

# %%
df['STOP']!='Unknown Location'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1151    False
# 1152    False
# 1153     True
# 1154     True
# 1155     True
# Name: STOP, Length: 1156, dtype: bool

# %% [markdown]
# 8. **Eliminamos del Dataframe los registros que contengan falso.**

# %%
df[df['STOP']!='Unknown Location']
# Out:
#             START_DATE          END_DATE  CATEGORY        START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
# ...                ...               ...       ...          ...
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business      Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business      Kar?chi
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business   Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business      Gampaha
# 1155            Totals               NaN       NaN          NaN
#
#                  STOP    MILES          PURPOSE
# 0         Fort Pierce      5.1   Meal/Entertain
# 1         Fort Pierce      5.0              NaN
# 2         Fort Pierce      4.8  Errand/Supplies
# ...

# %% [markdown]
# 9. **Sobreescribimos del Dataframe (df)**
#
# Para eliminar de nuestro análisis, es decir que el documento de origen de los datos (csv) siguer sin cambios, asignamos el resultado del filtrado.

# %%
df=df[df['STOP']!='Unknown Location']

# %% [markdown]
# 10. **Volvemos a imprimir el dataframe**
#
# En este resultado podemos observar que el nuevo dataframe cuenta solo con **1007** filas a diferencia del original que tenía **1156**, es decir, se eliminaron **149** registros que no tenían un destino localizable.

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY        START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
# ...                ...               ...       ...          ...
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business      Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business      Kar?chi
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business   Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business      Gampaha
# 1155            Totals               NaN       NaN          NaN
#
#                  STOP    MILES          PURPOSE
# 0         Fort Pierce      5.1   Meal/Entertain
# 1         Fort Pierce      5.0              NaN
# 2         Fort Pierce      4.8  Errand/Supplies
# ...

# %% [markdown]
# 11. **Repetimos el proceso de limpieza ahora para los viajes que no tienen un origen localizable (START).**
#
# En este caso, hacemos toda la limpieza en una sola operación, obteniendo una actualización del df que ocuparemos para el análisis de datos, reduciendo de **1007** a **945** registros, intuyendeo que hay **62** viajes que tuvieron un destino (STOP) pero no un origen (START).

# %%
df=df[df['START']!='Unknown Location']
df
# Out:
#             START_DATE          END_DATE  CATEGORY        START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
# ...                ...               ...       ...          ...
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business      Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business      Kar?chi
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business   Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business      Gampaha
# 1155            Totals               NaN       NaN          NaN
#
#                  STOP    MILES          PURPOSE
# 0         Fort Pierce      5.1   Meal/Entertain
# 1         Fort Pierce      5.0              NaN
# 2         Fort Pierce      4.8  Errand/Supplies
# ...

# %% [markdown]
# 12. **Conceptos de Repaso**
#
# ***12.1 Funciones o Métodos Python:***
#
#
# Una función o método es un bloque de código reutilizable que realiza una tarea específica.
#
# Sirve para evitar repetir instrucciones y organizar mejor los programas.
#
# En el lenguaje de Programación de Python las funciones son declaradas con la palabra reservada **def**, y para ejecutarlas basta con escribir el nombre que se le asignó a la misma, el uso de () es para evitar los datos de entrada en caso de que sean necesarios.

# %% [markdown]
# *Definición:*

# %%
def saludar():
    print("Hola, bienvenid@ a Python para el analisis de datos")

# %% [markdown]
# *Llamado:*

# %%
saludar()
# Out:
# Hola, bienvenid@ a Python para el analisis de datos

# %% [markdown]
# ***12.2 Funciones que reciben un parámetro o datos de entrada***
#
# En algunas ocasiones es necesario enviar datos para la ejecucuión del método, para ello debemos declararlo en la definición de la función entre ( ).

# %% [markdown]
# *Definición:*

# %%
def saludar_nombre(nombre):
    return f"Hola, {nombre} Bienvenid@ a Python para el análisis de datos."

# %% [markdown]
# *Llamado:*

# %%
saludar_nombre("Samuel")
# Out:
# 'Hola, Samuel Bienvenid@ a Python para el análisis de datos.'

# %%
saludar_nombre("Ana")
# Out:
# 'Hola, Ana Bienvenid@ a Python para el análisis de datos.'

# %% [markdown]
# ***12.3 Funciones que mandan llamar otras funciones y que regresan el resultado de un procesamiento***
#
# En este caso utilizaremos una función predefinida en Python denominada **replace** que nos permite sustituir letras en una cadena de texto.

# %% [markdown]
# *Definición*

# %%
def sustituir_vocales(texto):
    texto = texto.replace("A", "4")
    texto = texto.replace("a", "4")

    texto = texto.replace("E", "3")
    texto = texto.replace("e", "4")

    texto = texto.replace("I", "1")
    texto = texto.replace("i", "1")

    texto = texto.replace("O", "0")
    texto = texto.replace("o", "0")

    texto = texto.replace("U", "∪")
    texto = texto.replace("u", "∪")

    return texto

# %% [markdown]
# *Llamado:*

# %%
print(sustituir_vocales(saludar_nombre("Samuel")))
# Out:
# H0l4, S4m∪4l B14nv4n1d@ 4 Pyth0n p4r4 4l 4nál1s1s d4 d4t0s.

# %% [markdown]
# **13. Limpieza de letras legibles**
#
# Ejecutamos el proceso de sustitución de las letras ilegibles (para este caso de estudio solo hay letras "a" con tilde que se cargaron con un ? y se limpian con una "a", para mejor comprensión del análisis.

# %%
df['START'] = df['START'].astype(str).str.replace('?', 'a')
df['STOP'] = df['STOP'].astype(str).str.replace('?', 'a')
df
# Out:
# C:\Users\PC-01\AppData\Local\Temp\ipykernel_3424\1219360620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['START'] = df['START'].astype(str).str.replace('?', 'a')
# C:\Users\PC-01\AppData\Local\Temp\ipykernel_3424\1219360620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['STOP'] = df['STOP'].astype(str).str.replace('?', 'a')
#             START_DATE          END_DATE  CATEGORY        START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# ...

# %% [markdown]
# 14. **Rellenar datos vacíos por un valor genérico asignado**
#
# Durante el proceso de Limpieza y Transformación de los datos, existe la posibilidad de corregir datos que no se encuentran registrados, para este caso usaremos una función de **Pandas** llamada *filna*, (sirve para rellenar los datos no disponibles (not avalaible), en este caso serán sustituidos por la palabra Others, en el dataframe original por eso se activa **inplace = True**

# %%
df['PURPOSE'].fillna('Others', inplace=True)
df
# Out:
# C:\Users\PC-01\AppData\Local\Temp\ipykernel_3424\2042178618.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PURPOSE'].fillna('Others', inplace=True)
# C:\Users\PC-01\AppData\Local\Temp\ipykernel_3424\2042178618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PURPOSE'].fillna('Others', inplace=True)
# ...

# %% [markdown]
# 15. **Medidas de Tendencia Central**
#
# Una vez terminada la fase de limpieza de datos, comenzamos con la Estadística Básica, en este caso consultaremos las medias de tendencia central siendo: Total, Media, Cuartiles, Desviación Estándar, Máximo y Mínimo.
#
# Utilizando el método **describe** de nuestro dataframe, se buscarán todos los datos cuantitativos (numéricos) de la muestra y realizará el cálculo de estos valores, para este caso en específico solo tenemos la columna **MILES**, la cual hace referencia al total de Millas Terrestres (1.609 Km) recorridas por el conductor en un servicio de viaje a través de UBER.

# %%
df.describe()
# Out:
#               MILES
# count    945.000000
# mean      22.809841
# std      397.276813
# min        0.500000
# 25%        2.600000
# 50%        5.300000
# 75%        9.900000
# max    12204.700000

# %% [markdown]
# Para el caso de Mediana y Moda, estas deben ser calculadas por separado a través de las funciones .mode y .median

# %%
print(df['MILES'].mode())
# Out:
# 0    9.9
# Name: MILES, dtype: float64

# %%
print(df['MILES'].median())
# Out:
# 5.3

# %% [markdown]
# En **conclusión** este dataframe nos permite analizar una pequeña muestra de ***945*** viajes realizados a través de la aplicación de UBER, determinando que la distancia mínima registrada es de ***.5 millas*** y la máxima de ***12,204.7 millas***, con un promedio de ***22.8 millas***, siendo la distancia más repetida de ***9.9 millas*** y la mediana de ***5.3 millas***

# %% [markdown]
# 16. **Limpieza de Datos: Segmentar la fecha del viaje, ignorando la HH:MM:SS.**

# %% [markdown]
# 16. **Graficación Básica para un análisis más Visual y Simplificado**

# %%
def val(value):
    value=str(value)
    value=value.split()
    return value[0].replace('-','/')
df['START_DATE']=df['START_DATE'].apply(val)

def val(value):
    value=str(value)
    value=value.split()
    return value[0].replace('-','/')
df['END_DATE']=df['END_DATE'].apply(val)
df
# Out:
# C:\Users\PC-01\AppData\Local\Temp\ipykernel_3424\701688281.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['START_DATE']=df['START_DATE'].apply(val)
# C:\Users\PC-01\AppData\Local\Temp\ipykernel_3424\701688281.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['END_DATE']=df['END_DATE'].apply(val)
#       START_DATE    END_DATE  CATEGORY        START             STOP    MILES  \
# 0     01/01/2016  01/01/2016  Business  Fort Pierce      Fort Pierce      5.1
# ...

# %% [markdown]
# 17. **Eliminamos la última fila de totales**
#
# La última fila de totales no es necesaria para la graficación dado que podría generar error en la presentación de datos, por ello la eliminamos del Dataframe usando el comando *drop* y el número de la posición de la fila a eliminar encerrada entre corchetes [ ].

# %%
df.drop([1155], inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.drop([1155], inplace=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %% [markdown]
# 18. **Eliminar los datos de los cuartiles menores**
#
# En esta sección del ejercicio se realiza un proceso de eliminación de valores atípicos (outliers) a partir de los percentiles de la columna **MILES**. Primero, se calculan los percentiles 5 y 95 con el fin de establecer un límite inferior y superior dentro de la distribución de los datos. Después, se filtran los registros para conservar únicamente aquellos valores que se encuentran dentro de estos límites, descartando los datos extremadamente bajos o altos que pueden influir negativamente en el análisis. Este procedimiento permite trabajar con un conjunto de datos más limpio y representativo, facilitando así la obtención de resultados más precisos y confiables durante el análisis de la información.

# %%
a=df['MILES'].quantile(0.95)
b=df['MILES'].quantile(0.05)
df3=df[df['MILES']>b]
df3=df[df['MILES']<a]
df3
# Out:
#       START_DATE    END_DATE  CATEGORY            START             STOP  \
# 0     01/01/2016  01/01/2016  Business      Fort Pierce      Fort Pierce
# 1     01/02/2016  01/02/2016  Business      Fort Pierce      Fort Pierce
# 2     01/02/2016  01/02/2016  Business      Fort Pierce      Fort Pierce
# 3     01/05/2016  01/05/2016  Business      Fort Pierce      Fort Pierce
# 5     01/06/2016  01/06/2016  Business  West Palm Beach  West Palm Beach
# ...          ...         ...       ...              ...              ...
# 1147  12/30/2016  12/30/2016  Business          Karachi          Karachi
# 1148  12/30/2016  12/30/2016  Business          Karachi          Karachi
# 1149  12/30/2016  12/30/2016  Business          Karachi          Karachi
# 1150  12/31/2016  12/31/2016  Business          Karachi          Karachi
# 1153  12/31/2016  12/31/2016  Business       Katunayake          Gampaha
#
#       MILES          PURPOSE
# 0       5.1   Meal/Entertain
# 1       5.0           Others
# ...

# %% [markdown]
# 19. **Calculo de Desviación Estandar**
#
# Para entender qué tan variables o dispersas son las distancias de los viajes.

# %%
df3['STD']=df.MILES.std()
df3
# Out:
# C:\Users\PC-01\AppData\Local\Temp\ipykernel_3424\672307851.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['STD']=df.MILES.std()
#       START_DATE    END_DATE  CATEGORY            START             STOP  \
# 0     01/01/2016  01/01/2016  Business      Fort Pierce      Fort Pierce
# 1     01/02/2016  01/02/2016  Business      Fort Pierce      Fort Pierce
# 2     01/02/2016  01/02/2016  Business      Fort Pierce      Fort Pierce
# 3     01/05/2016  01/05/2016  Business      Fort Pierce      Fort Pierce
# 5     01/06/2016  01/06/2016  Business  West Palm Beach  West Palm Beach
# ...          ...         ...       ...              ...              ...
# 1147  12/30/2016  12/30/2016  Business          Karachi          Karachi
# ...

# %% [markdown]
# 20. **Estimar el Valor de Z-Score o Puntuación Z**
#
# Con la finalidad de estimar la dispercion de los datos, es decir que tan variados o diferentes son, utilizamos esta formula estadística para poder continuera con el analisis EDA (Exploratory Data Analisys).

# %%
df3['Z']=(df.MILES-df.MILES.mean())/df.MILES.std()
df3
# Out:
# C:\Users\PC-01\AppData\Local\Temp\ipykernel_3424\2738585948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Z']=(df.MILES-df.MILES.mean())/df.MILES.std()
#       START_DATE    END_DATE  CATEGORY            START             STOP  \
# 0     01/01/2016  01/01/2016  Business      Fort Pierce      Fort Pierce
# 1     01/02/2016  01/02/2016  Business      Fort Pierce      Fort Pierce
# 2     01/02/2016  01/02/2016  Business      Fort Pierce      Fort Pierce
# 3     01/05/2016  01/05/2016  Business      Fort Pierce      Fort Pierce
# 5     01/06/2016  01/06/2016  Business  West Palm Beach  West Palm Beach
# ...          ...         ...       ...              ...              ...
# ...

# %% [markdown]
# 21. **Filtramos aquello que no este en el rango de -1 y 1**

# %%
df['MILES'].describe()
# Out:
# count    944.000000
# mean       9.905297
# std       21.472805
# min        0.500000
# 25%        2.600000
# 50%        5.300000
# 75%        9.900000
# max      310.300000
# Name: MILES, dtype: float64

# %%
df3['MILES'].describe()
# Out:
# count    896.000000
# mean       6.344196
# std        4.849186
# min        0.500000
# 25%        2.500000
# 50%        4.900000
# 75%        9.025000
# max       25.600000
# Name: MILES, dtype: float64

# %%
df3=df3[(df3.Z>-1) & (df3.Z<1)]
df3
# Out:
#       START_DATE    END_DATE  CATEGORY            START             STOP  \
# 0     01/01/2016  01/01/2016  Business      Fort Pierce      Fort Pierce
# 1     01/02/2016  01/02/2016  Business      Fort Pierce      Fort Pierce
# 2     01/02/2016  01/02/2016  Business      Fort Pierce      Fort Pierce
# 3     01/05/2016  01/05/2016  Business      Fort Pierce      Fort Pierce
# 5     01/06/2016  01/06/2016  Business  West Palm Beach  West Palm Beach
# ...          ...         ...       ...              ...              ...
# 1147  12/30/2016  12/30/2016  Business          Karachi          Karachi
# 1148  12/30/2016  12/30/2016  Business          Karachi          Karachi
# 1149  12/30/2016  12/30/2016  Business          Karachi          Karachi
# 1150  12/31/2016  12/31/2016  Business          Karachi          Karachi
# 1153  12/31/2016  12/31/2016  Business       Katunayake          Gampaha
#
#       MILES          PURPOSE        STD         Z
# ...

# %% [markdown]
# 22. **Graficación Básica para un Analisis más Visual y Simplificado**

# %%
mat.title('Total Distance Travelled in MILES')
sea.histplot(df3.MILES, color='Purple')
mat.show()

# %% [markdown]
# 23. **Grafico de Clasificación de Viajes por *CATEGORIA***

# %%
fig, ax = mat.subplots(figsize=(8,5))

grafica = sea.countplot(
    data = df,
    x = 'CATEGORY',
    hue = 'CATEGORY',
    palette = 'Set2',
    legend = False,
    ax = ax
)

#Titulo
ax.set_title('Viaje por Categoria')

#Agregar etiquetas con totales
for container in ax.containers:
    ax.bar_label(container)

mat.show()

# %% [markdown]
# 24. **Grafica de Viajes por Proposito (PURPOSE)**

# %%
fig, ax = mat.subplots(figsize=(10,6))

grafica = sea.countplot(
    data = df,
    y = 'PURPOSE',
    hue = 'PURPOSE',
    dodge = False,
    palette = 'viridis',
    legend = False,

)

#Titulo
ax.set_title('Purpose of Visit (Others = Not MENTIONED)')

#Agregar etiquetas con totales
for container in ax.containers:
    ax.bar_label(container)

mat.show()

# %% [markdown]
# 25. **Grafico de Lugar de Abordaje (START)**

# %%
fig, ax = mat.subplots(figsize=(15,30))

#Ordenar alafabeticamente
order = sorted(df['START'].dropna().unique())

grafica = sea.countplot(
    data = df,
    y = 'START',
    order=order,
    hue = 'START',
    dodge = False,
    palette = 'viridis',
    legend = False,
    ax = ax
)

#Titulo
ax.set_title('Start Location')

#Agregar etiquetas con totales
for container in ax.containers:
    ax.bar_label(container)

mat.show()

# %% [markdown]
# 26. **Grafica de lugar de llegada (STOP)**

# %%
fig, ax = mat.subplots(figsize=(15,50))

#Oedenar alfaveticamente
orden = sorted(df['STOP'].dropna().unique())

grafica = sea.countplot(
    data = df,
    y = 'STOP',
    order = orden,
    hue = 'STOP',
    dodge = False,
    palette = 'viridis',
    legend = False,
    ax = ax
)

#Titulo
ax.set_title('Lugar de Llegada')

#Agregar etiquetas con totales
for container in ax.containers:
    ax.bar_label(container)

mat.show()

# %% [markdown]
# **Conclusión:**
#
# Al finalizar esta práctica, puedo decir que reafirmé los conocimientos sobre los fundamentos del análisis de datos, son la base real para tomar decisiones inteligentes en el mundo digital actual. En un contexto donde el e-commerce y los negocios digitales dependen cada vez más de la información para entender a sus usuarios, optimizar rutas, personalizar experiencias y reducir costos, saber manejar, limpiar e interpretar datos marca la diferencia entre adivinar y decidir con evidencia. En esta práctica trabajamos con un dataset real de viajes de Uber, lo cual nos permitió aterrizar conceptos que antes veíamos de forma aislada. Empezamos con lo básico pero esencial: importar librerías como pandas y numpy, cargar el archivo CSV en un DataFrame y empezar a explorar su estructura con comandos sencillos y filtros condicionales. Uno de los puntos más valiosos fue retomar temas de probabilidad y estadística, pero ahora aplicados a un escenario real. Calculamos medidas de tendencia central (media, mediana y moda) Entramos en conceptos nuevos pero súper útiles: ETL (Extract, Transform, Load) para entender el flujo de trabajo con datos, y EDA (Exploratory Data Analysis) como metodología para "conversar" con los datos antes de modelar. Aprendimos a calcular percentiles (5 y 95) para identificar y filtrar outliers, a interpretar la desviación estándar (~21.47) como medida de dispersión, y a usar la puntuación Z para estandarizar valores y decidir cuáles quedaban dentro de un rango "normal" (entre -1 y 1 en nuestro caso). Las gráficas que generamos con seaborn y matplotlib nos dieron una visión más intuitiva de los resultados:
#
# El histograma de millas mostró una distribución altamente sesgada a la derecha, confirmando visualmente lo que nos decían las estadísticas: la mayoría de los viajes son cortos, pero unos pocos muy largos "jalan" la media hacia arriba.
# El gráfico de barras por CATEGORY dejó claro que el 93% de los viajes fueron clasificados como "Business", lo que sugiere que este dataset refleja principalmente uso corporativo o profesional de la plataforma.
# Al visualizar PURPOSE, vimos que los motivos más frecuentes fueron "Others" (reviamente se modificó, ya que algunos usuarios decidieron no colocar el propósito del viaje, por lo que esta barra presenta una mayor cantidad de datos.), “Meeting” y "Meal/Entertain", lo que podría ayudar a una empresa a anticipar demanda en ciertos horarios o zonas.
# Los mapas de barras de START y STOP nos permitieron identificar patrones geográficos: Fort Pierce, Cary y Karachi aparecieron como puntos recurrentes, lo que en un contexto real serviría para optimizar la asignación de conductores o promociones localizadas.
